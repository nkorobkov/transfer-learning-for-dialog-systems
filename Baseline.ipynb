# %%
import json
import csv
import random
import torch
import torch.nn as nn
import numpy as np
# use this library https://github.com/facebookresearch/fastText/tree/master/python
import fastText

# %%
trainset = []
with open('data/snips_processed/snips_train.csv', 'r') as f:
    reader = csv.reader(x.replace('\0', '') for x in f)
    for line in reader:
        trainset.append(line)
trainset = np.array(trainset)

testset = []
with open('data/snips_processed/snips_test.csv', 'r') as f:
    reader = csv.reader(x.replace('\0', '') for x in f)
    for line in reader:
        testset.append(line)
testset = np.array(testset)

labels = list(set(trainset[:,0]))
lab2id = {}
id2lab = {}

for i in range(len(labels)):
    lab2id[labels[i]] = i
    id2lab[i] = labels[i]

# %%
sv_model = fastText.load_model('data/cc.sv.300.bin')
en_model = fastText.load_model('data/cc.en.300.bin')

# %%
def sentence_vec(sentence, model):
    result = np.zeros((1, 300))
    sentence = sentence.strip()
    for word in sentence:
        result += model.get_word_vector(word.lower())
    return result/len(sentence)

# %%
def prepare_pair(label, sentence, model):
    return (lab2id[label]),(sentence_vec(sentence, model))

def prepare_pairs(data, lang = 'en'):
    if lang == 'en':
        model = en_model
        slab = 1
    elif lang == 'sv':
        model = sv_model
        slab = 2
    else:
        raise RuntimeError('lang is not supported')
    labels = []
    vectors = []
    for sample in data:
        l, v = prepare_pair(sample[0], sample[slab], model)
        labels.append(l)
        vectors.append(v)
        
    return labels, vectors

# %%
class Baseline(nn.Module):
    def __init__(self, in_size = 300, out_size = 10):
        super(Baseline, self).__init__()

        self.W = nn.Linear(300, 10)
        self.out = nn.LogSoftmax(2)
        
    def forward(self, x):
        x = self.W(x)
        return self.out(x)

# %%
def train(model, criterion, optimizer, labels, vectors):
    model.zero_grad()
    loss = 0
    
    vectors = torch.tensor(vectors).float()
    labels = torch.tensor(labels)
    
    model_out = model.forward(vectors)
    loss += criterion(model_out[:,0], labels)
    
    loss.backward()
    optimizer.step()
    
    return loss.item()/len(labels)

# %%
def eval(model, labels, vectors):
    with torch.no_grad():
        vectors = torch.tensor(vectors).float()
        labels = torch.tensor(labels)
    
        model_out = model.forward(vectors)
        right = 0
        
        for i  in range(len(model_out)):
            k, v = model_out[i].topk(1)
            predicted, true = v.item(), labels[i].item()
            if predicted == true:
                right +=1

                
        loss = criterion(model_out[:,0], labels)
        return loss.item(), right/len(model_out)

# %%
net = Baseline()
optimizer = torch.optim.Adam(net.parameters())
criterion = torch.nn.NLLLoss()
labs, vecs = prepare_pairs(trainset, lang = 'sv')
labst, vecst = prepare_pairs(testset, lang = 'sv')


for i in range(4001):
    loss = train(net, criterion, optimizer, labs, vecs)
    if not i% 100:
        eval_loss, acc = eval(net, labst, vecst)
        print('#{:4d}, train loss: {:3f}, eval loss: {:3f}, acc = {:3f}'.format(i, loss, eval_loss, acc))
# Out:
# #   0, train loss: 0.000209, eval loss: 2.249134, acc = 0.697373
# # 100, train loss: 0.000052, eval loss: 0.572726, acc = 0.851026
# # 200, train loss: 0.000040, eval loss: 0.440538, acc = 0.851026
# # 300, train loss: 0.000036, eval loss: 0.396479, acc = 0.851026
# # 400, train loss: 0.000033, eval loss: 0.369428, acc = 0.851745
# # 500, train loss: 0.000031, eval loss: 0.349387, acc = 0.853544
# # 600, train loss: 0.000030, eval loss: 0.333423, acc = 0.857143
# # 700, train loss: 0.000029, eval loss: 0.320255, acc = 0.861821
# # 800, train loss: 0.000028, eval loss: 0.309168, acc = 0.863980
# # 900, train loss: 0.000027, eval loss: 0.299699, acc = 0.869377
# #1000, train loss: 0.000026, eval loss: 0.291517, acc = 0.874775
# #1100, train loss: 0.000026, eval loss: 0.284377, acc = 0.879813
# #1200, train loss: 0.000025, eval loss: 0.278093, acc = 0.882332
# #1300, train loss: 0.000025, eval loss: 0.272518, acc = 0.885570
# #1400, train loss: 0.000024, eval loss: 0.267535, acc = 0.889529
# #1500, train loss: 0.000024, eval loss: 0.263050, acc = 0.892767
# #1600, train loss: 0.000023, eval loss: 0.258988, acc = 0.893847
# #1700, train loss: 0.000023, eval loss: 0.255287, acc = 0.896725
# #1800, train loss: 0.000023, eval loss: 0.251896, acc = 0.897085
# #1900, train loss: 0.000023, eval loss: 0.248772, acc = 0.898525
# #2000, train loss: 0.000022, eval loss: 0.245881, acc = 0.899964
# #2100, train loss: 0.000022, eval loss: 0.243193, acc = 0.901044
# #2200, train loss: 0.000022, eval loss: 0.240684, acc = 0.902123
# #2300, train loss: 0.000022, eval loss: 0.238331, acc = 0.904642
# #2400, train loss: 0.000022, eval loss: 0.236119, acc = 0.905002
# #2500, train loss: 0.000021, eval loss: 0.234032, acc = 0.905362
# #2600, train loss: 0.000021, eval loss: 0.232056, acc = 0.907521
# #2700, train loss: 0.000021, eval loss: 0.230181, acc = 0.907881
# #2800, train loss: 0.000021, eval loss: 0.228397, acc = 0.908600
# #2900, train loss: 0.000021, eval loss: 0.226696, acc = 0.909680
# #3000, train loss: 0.000021, eval loss: 0.225071, acc = 0.912918
# #3100, train loss: 0.000020, eval loss: 0.223516, acc = 0.913278
# #3200, train loss: 0.000020, eval loss: 0.222025, acc = 0.913278
# #3300, train loss: 0.000020, eval loss: 0.220594, acc = 0.914718
# #3400, train loss: 0.000020, eval loss: 0.219218, acc = 0.914718
# #3500, train loss: 0.000020, eval loss: 0.217895, acc = 0.915077
# #3600, train loss: 0.000020, eval loss: 0.216621, acc = 0.915437
# #3700, train loss: 0.000020, eval loss: 0.215394, acc = 0.916877
# #3800, train loss: 0.000020, eval loss: 0.214211, acc = 0.917956
# #3900, train loss: 0.000020, eval loss: 0.213069, acc = 0.918676
# #4000, train loss: 0.000020, eval loss: 0.211968, acc = 0.918676

# %%
net = Baseline()
optimizer = torch.optim.Adam(net.parameters())
criterion = torch.nn.NLLLoss()
labs, vecs = prepare_pairs(trainset, lang = 'en')
labst, vecst = prepare_pairs(testset, lang = 'en')


for i in range(4001):
    loss = train(net, criterion, optimizer, labs, vecs)
    if not i% 100:
        eval_loss, acc = eval(net, labst, vecst)
        print('#{:4d}, train loss: {:3f}, eval loss: {:3f}, acc = {:3f}'.format(i, loss, eval_loss, acc))
# Out:
# #   0, train loss: 0.000214, eval loss: 2.296857, acc = 0.148974
# # 100, train loss: 0.000048, eval loss: 0.526288, acc = 0.851026
# # 200, train loss: 0.000037, eval loss: 0.406894, acc = 0.851026
# # 300, train loss: 0.000033, eval loss: 0.360803, acc = 0.853185
# # 400, train loss: 0.000030, eval loss: 0.331020, acc = 0.862540
# # 500, train loss: 0.000028, eval loss: 0.309052, acc = 0.870817
# # 600, train loss: 0.000027, eval loss: 0.292021, acc = 0.879813
# # 700, train loss: 0.000026, eval loss: 0.278468, acc = 0.890248
# # 800, train loss: 0.000025, eval loss: 0.267494, acc = 0.898884
# # 900, train loss: 0.000024, eval loss: 0.258484, acc = 0.902123
# #1000, train loss: 0.000023, eval loss: 0.251004, acc = 0.903922
# #1100, train loss: 0.000023, eval loss: 0.244733, acc = 0.908960
# #1200, train loss: 0.000022, eval loss: 0.239429, acc = 0.911479
# #1300, train loss: 0.000022, eval loss: 0.234910, acc = 0.912199
# #1400, train loss: 0.000021, eval loss: 0.231031, acc = 0.914358
# #1500, train loss: 0.000021, eval loss: 0.227682, acc = 0.917596
# #1600, train loss: 0.000021, eval loss: 0.224775, acc = 0.919036
# #1700, train loss: 0.000021, eval loss: 0.222237, acc = 0.920115
# #1800, train loss: 0.000020, eval loss: 0.220012, acc = 0.921555
# #1900, train loss: 0.000020, eval loss: 0.218054, acc = 0.922274
# #2000, train loss: 0.000020, eval loss: 0.216324, acc = 0.922994
# #2100, train loss: 0.000020, eval loss: 0.214789, acc = 0.924433
# #2200, train loss: 0.000020, eval loss: 0.213423, acc = 0.925873
# #2300, train loss: 0.000020, eval loss: 0.212205, acc = 0.926232
# #2400, train loss: 0.000020, eval loss: 0.211115, acc = 0.926592
# #2500, train loss: 0.000020, eval loss: 0.210136, acc = 0.927312
# #2600, train loss: 0.000020, eval loss: 0.209255, acc = 0.927312
# #2700, train loss: 0.000019, eval loss: 0.208460, acc = 0.927672
# #2800, train loss: 0.000019, eval loss: 0.207741, acc = 0.928032
# #2900, train loss: 0.000019, eval loss: 0.207089, acc = 0.927672
# #3000, train loss: 0.000019, eval loss: 0.206495, acc = 0.927312
# #3100, train loss: 0.000019, eval loss: 0.205953, acc = 0.928392
# #3200, train loss: 0.000019, eval loss: 0.205457, acc = 0.928392
# #3300, train loss: 0.000019, eval loss: 0.205001, acc = 0.928392
# #3400, train loss: 0.000019, eval loss: 0.204582, acc = 0.929111
# #3500, train loss: 0.000019, eval loss: 0.204194, acc = 0.929471
# #3600, train loss: 0.000019, eval loss: 0.203834, acc = 0.929471
# #3700, train loss: 0.000019, eval loss: 0.203498, acc = 0.929471
# #3800, train loss: 0.000019, eval loss: 0.203185, acc = 0.929831
# #3900, train loss: 0.000019, eval loss: 0.202891, acc = 0.930191
# #4000, train loss: 0.000019, eval loss: 0.202613, acc = 0.930191

# %%
def eval_visual(model, labels, vectors):
    with torch.no_grad():
        vectors = torch.tensor(vectors).float()
        labels = torch.tensor(labels)
    
        model_out = model.forward(vectors)
        right = 0
        wrong = 0
        for i  in range(len(model_out)):
            k, v = model_out[i].topk(1)
            predicted, true = v.item(), labels[i].item()
            if predicted == true:
                right +=1
            else:
                print(id2lab[predicted], id2lab[true])
                wrong +=1
                
        print('{} out of {} = {}'.format(right, right+wrong, right/(right+wrong)))

# %%
eval_visual(net, labst, vecst)
# Out:
# ComparePlaces GetPlaceDetails
# SearchPlace RequestRide
# BookRestaurant GetWeather
# GetPlaceDetails GetWeather
# RequestRide GetTrafficInformation
# SearchPlace GetPlaceDetails
# GetTrafficInformation GetDirections
# GetPlaceDetails GetWeather
# GetDirections GetPlaceDetails
# GetWeather GetPlaceDetails
# GetDirections SearchPlace
# SearchPlace ShareETA
# SearchPlace GetPlaceDetails
# GetPlaceDetails GetTrafficInformation
# GetTrafficInformation GetWeather
# GetWeather ShareCurrentLocation
# GetPlaceDetails ComparePlaces
# SearchPlace BookRestaurant
# GetPlaceDetails GetTrafficInformation
# SearchPlace RequestRide
# ComparePlaces GetPlaceDetails
# GetWeather GetPlaceDetails
# GetDirections GetPlaceDetails
# GetWeather GetPlaceDetails
# GetPlaceDetails GetWeather
# RequestRide GetWeather
# BookRestaurant GetWeather
# BookRestaurant GetTrafficInformation
# 50 out of 78 = 0.6410256410256411

# %%
trainset
# Out:
# array([['RateBook', 'rate the current textbook zero out of 6 points'],
#        ['BookRestaurant',
#         'restaurant in Elberta for alma, deana and olga at 18:49:20 that serves tsipouro'],
#        ['SearchScreeningEvent',
#         'What movies are currently at Star Theatres?'],
#        ...,
#        ['PlayMusic', 'Please play Different Slanguages by Fred Labour.'],
#        ['PlayMusic', 'play some King Tubby from the eighties'],
#        ['AddToPlaylist',
#         'add M-CABI to the playlist named Pre-Party R&B Jams']],
#       dtype='<U186')

# %%
lab2id
# Out:
# {'what films are on the movie schedule for ten at a close by theater': 0,
#  'play new music by Elmore James with google music': 1,
#  'What is the weather going to be like in Flint Hill in 9 years  ': 2,
#  'add the artist Tomohisa Yamashita to the conexiones playlist': 3,
#  'Rate The Hollow Man 5 points': 4,
#  'Give A History of the Mind a 2 out of 6 points.': 5,
#  'add spanish castle magic to Daily Lift': 6,
#  'Rate the current novel a 3. ': 7,
#  'Can you locate the novel, Ismol Family': 8,
#  'Will it be rainy this Monday in Le Center, Thailand': 9,
#  'What will the weather be in Grand Coteau UT at six pm?': 10,
#  'whats the closest movie theatre showing animated movies': 11,
#  'My group of seven wants to eat at Yogurt Mountain in Slick tonight.': 12,
#  "I want to hear Sarban's greatest hits": 13,
#  'book a pub for pepperoni near their house and not far': 14,
#  'Book me a reestaurant that is close in the country of Cocos Islands': 15,
#  'show Chocolate Rain creativity': 16,
#  'Add another album to my keep calm playlist. ': 17,
#  'Book a restaurant in Palestine for 8 people at 9 AM': 18,
#  'Reserve a table at a restaurant with wifi in France': 19,
#  'Is it warm in Vietnam': 20,
#  'Add sammy hagar to Ultra Metal': 21,
#  'where can I find the game A Little Bit of Mambo': 22,
#  'Show the Minutes to Midnight photograph': 23,
#  'Put jiro in my clásicos del hip hop español playlist. ': 24,
#  'Play Keep Your Right Up song': 25,
#  'Play a top song by Carson Parks on Groove Shark': 26,
#  'Will it be chillier in Suwannee': 27,
#  'Weather on Croatan National Forest on jan. 21': 28,
#  'What cinema is showing Ice Station Zebra at 07:25 P.M.?': 29,
#  'Can you play fifties theme music by Mohsen Chavoshi': 30,
#  'book a table for ten people': 31,
#  'me, maggie and ellen want to eat at Lentil as Anything': 32,
#  'Where is Walt: The Man Behind the Myth playing': 33,
#  'find The Angry Birds Movie': 34,
#  "I'm looking for the show called The Origin of the Milky Way": 35,
#  'Find The Dressmaker.': 36,
#  'Let me get the movie schedule for lunch time.': 37,
#  'give this textbook four stars': 38,
#  'Weather for Douthat State Park on Mar. 10': 39,
#  'I want to listen to the song The Loving Spirit': 40,
#  'Is it going to be warm in Cottageville': 41,
#  'Add See Me Now to my enamorándose playlist': 42,
#  'edit Top 100 Indie Tracks on Spotify playlist by adding Smokefree RockQuest 2005': 43,
#  'Book reservations at a restaurant in Iron Springs': 44,
#  'Book a reservation for a southern brazilian restaurant for 10 people within walking distance of Broadway-Lafayette St': 45,
#  "What's the weather forecast for Etna Green in 11 months? ": 46,
#  'Add Written in Red to my cleaning the house playlist. ': 47,
#  'Play fifties music by Ahmed Abdul Malik': 48,
#  'I have a party of 10 that would like to eat outdoor at a tavern.': 49,
#  'my Disco Forever playlist needs an album by sawai gandharva.': 50,
#  'Is it warm here now?': 51,
#  'give 4 out of 6 stars to current chronicle': 52,
#  'I want to watch The Original Recordings': 53,
#  'book at table at Forest Av restaurant close-by for 2 1 second from now': 54,
#  'Add another tune to my Lo mejor del Rock de España playlist. ': 55,
#  'rate the book chronicle The Obama Nation a 4': 56,
#  "Add jenifer to Rock the 2000's": 57,
#  'Is there a blizzard in Stonewood?': 58,
#  'I need a table for 3 at David Whitney House in Brazil': 59,
#  'How will the weather be at 8 am in CT?': 60,
#  'find Carry me in your dreams': 61,
#  'Please play a song for me from 1959': 62,
#  'this novel gets 0 out of 6 points': 63,
#  'need a table at a highly rated south tyrolean joint': 64,
#  'Play me a song by Michael Diamond': 65,
#  "rate tune to 90's Baby Makers": 66,
#  'book rosalie stewart and evelyn at a restaurant': 67,
#  'Search for the song called Journal of the American Statistical Association': 68,
#  'book a table for me and savannah in Lauderdale Lakes': 69,
#  'find movies close by': 70,
#  'Rate The A-Z Guide to Arranged Marriage 0 of 6': 71,
#  'What time is a movie in the neighbourhood': 72,
#  'Rate The Documents in the Case series two of 6': 73,
#  'Please get me the work Shirley aviatrice.': 74,
#  'Rate The Australian Ugliness 3 points': 75,
#  'Give this novel two out of 6 stars': 76,
#  'Make a reservation for four at a pub in Sugarville.': 77,
#  'I give the previous series four stars.': 78,
#  'find Doggy Day School, an album': 79,
#  'Add Jonathan Arons to my Indie Electronics playlist': 80,
#  'give this book titled Othappu zero points': 81,
#  'play laura love songs from 1959': 82,
#  'Will it be warmer at lunch in Prentice, Armenia': 83,
#  'I want to book the distant downtown Tribeca Grill for august the twenty-third, 2025 for wilda and jacklyn': 84,
#  'book Red Crown Tourist Court now for ten not far from Tin City': 85,
#  "What's the weather going to be like around Lewis and Clark Trail sixteen hours from now?": 86,
#  "What's the weather like at Powers Lake?": 87,
#  'Rate The Masks of Time zero of 6 stars': 88,
#  'book a spot for 3 in Egypt at five': 89,
#  "I'd like to eat at a top-rated place on nov. the twenty-sixth in the food court, I need reservations for 7 in the city of Kane or somewhere near there.": 90,
#  'rate the current saga a 4': 91,
#  'Add Welcome to the Cruel World to my Reggae Classics': 92,
#  'play Paula Campbell music from 1993': 93,
#  'book Itsu for Tonight': 94,
#  'book a meal for four in DC': 95,
#  'I want to eat at a Escondida South Carolina restaurant for 8 people': 96,
#  'Please book a coffeehouse restaurant type room to accommodate gretchen, trisha and amber which serves pastelaria dish': 97,
#  'rate Varney the Vampire with 1 points': 98,
#  'play Morning Song': 99,
#  'play a chant by Marina Verenikina': 100,
#  'The Rats of Hamelin deserves zero points': 101,
#  'Where can I find the photograph of Mr Blobby': 102,
#  'Will there be a depression in the weather here on cyber monday?': 103,
#  'I would give Things Fall Apart 3 stars': 104,
#  'I need to know when Sensation in Morgan’s Creek is playing': 105,
#  'Add you put a move on my heart to the martin garrix show ': 106,
#  'Rate Richard Carvel 4 out of 6': 107,
#  'The Only Snow in Havana deserves a best rating of 6 and 5 points': 108,
#  'party for 2 in Cleveland': 109,
#  'When is Bless the Child playing at the movie theatre': 110,
#  'Find Wish You Were Here.': 111,
#  'Add tune to my hot 50': 112,
#  'Play Greg Raposo songs from the thirties': 113,
#  'this current book is worth five': 114,
#  'book a spot at a pub with tatar in Cambodia': 115,
#  'For the textbook, out of 6 possible I give the following one a 3.': 116,
#  'what will the weather be at Mu Ko Phetra National Park on Administrative Professionals Day': 117,
#  'Play music on Deezer.': 118,
#  'What is going on with the weather far from my current location': 119,
#  'will it be colder in AZ than TX today': 120,
#  'Where can I get the novel Flesh-Colored Horror': 121,
#  'put Edwyn Collins onto my Trabajo Relax playlist': 122,
#  'give me the forecast for here on February the sixteenth, 2022': 123,
#  'where is Puthri playing': 124,
#  'show creativity of photograph of My Wonderful Day': 125,
#  'what theaters are showing A Lonely Place to Die – Todesfalle Highlands starting at 14:40': 126,
#  'Play Night Electric Night on Iheart': 127,
#  'Will there be a blizzard in Oregon?': 128,
#  'Book a restaurant in Liechtenstein for seven people.': 129,
#  'Is it hot in FL': 130,
#  'What is the weather doing in South Carolina right now?': 131,
#  'Dragon Age: The Stolen Throne gets 1 points': 132,
#  'Play chant from Freddy Fender on iheart': 133,
#  'Find me the novel titled Fertile Ground': 134,
#  'Can you get me a reservation at WWE The World around Av U': 135,
#  'I want to book a pub in MS that serves festoni': 136,
#  "What's the weather forecast for my current location on jun. 2?": 137,
#  'find a saga called The Life of Riley': 138,
#  'Rate this chronicle a 4': 139,
#  'My current textbook should have a rating value of 5 and a best rating of 6': 140,
#  'Play The Tyranny Of Distance by Willy Mason.': 141,
#  'find the novel A Hat in Time ': 142,
#  'show weather forecast at three am.in Wauregan': 143,
#  'will there be hail in Kaffir': 144,
#  'Play Soldier Boy from Melody Gardot': 145,
#  'Add the artist jill vidal to my Sinfonía Hipster playlist': 146,
#  'search for the album Frog and the Birdsong': 147,
#  "Let's play the album Handover on Deezer": 148,
#  'put dj green lantern on my Targeted playlist': 149,
#  'put Kan Mikami on Pre-Party R&B Jams': 150,
#  'Please tell me the movie schedules ': 151,
#  'Show movie schedules of film nearby': 152,
#  'Add Tranquility to the Latin Pop Rising playlist. ': 153,
#  'book a table for 3 far from Tullytown at a coffeehouse with a smoking room': 154,
#  'give 1 points to The Duel: Pakistan on the Flight Path of American Power saga\n': 155,
#  'add 9AM in Dallas to my classical music for smart kids': 156,
#  'book four people at a Madagascar bar': 157,
#  'add track Nature Noise to my playlist': 158,
#  'find Switching Channels': 159,
#  'Play a song from 1950': 160,
#  'What time is The Message playing at Loews Cineplex?': 161,
#  'Give this album 2 / 6.': 162,
#  'Can You tell me the Actors of the saga awards/': 163,
#  'Play me the show Cheaper By the Dozen 2': 164,
#  'Play music by Ian Haugland': 165,
#  'What time is High Tide at Noon showing': 166,
#  'book a restaurant for nine on 16 hours from now': 167,
#  'add adele onto funtime activity playlist': 168,
#  'add Días Felices to my todo reggaeton playlist': 169,
#  'please add george nooks to my electronow playlist': 170,
#  'turn on Last Fm': 171,
#  'I need to know is it freezing in MN at 01:27 pm': 172,
#  'In my playlist Rock Gaming add Mariem Hassan con Leyoad': 173,
#  'what is the Bolsa Chica State Beach forecast for foggy conditions': 174,
#  'Tell me the weather forecast for Niue': 175,
#  'add Devil Pray to my party list': 176,
#  'Add some martine mccutcheon to my original columbia jazzmasters list': 177,
#  'Will it be cloudy one hour from now in my current position': 178,
#  'Show Famous Classic Tales television show': 179,
#  'What time is Too Young to Marry showing': 180,
#  'Find the album titled Spasmolytic': 181,
#  "add this tune to my It's a Southern Thing playlist": 182,
#  'Incorporate Moribund the Burgermeister into the 50 Shades of Love playlist. ': 183,
#  'rate Until I Find You four points': 184,
#  'give this textbook a 4': 185,
#  'Find a soundtrack called New Religion.': 186,
#  'Will it be overcast during meal time in NH?': 187,
#  'Please make reservations for me and my roommate somewhere in Bouvet Island': 188,
#  "In Apr., I'd like to eat at a pub Manack Montana with 4 people": 189,
#  'Book a popular joint in Ocean Gate for seven people at elevenses.': 190,
#  'add an album in Sweet Soul Chillout': 191,
#  'find American Psychologist, a game': 192,
#  'is Unbeatable Harold at Century Theatres': 193,
#  'this tune should go on my coffee table jazz playlist': 194,
#  'I would give this current novel one stars': 195,
#  'Play some Ray Williams music from the nineties on spotify': 196,
#  'Play some sixties on netflix': 197,
#  'I need a reservation for next week with a party of six': 198,
#  'I need a dinner reservation in three months for a restaurant in Hills and Dales.': 199,
#  'I would give this current novel a value of 3 and a rating of 6': 200,
#  'Give 4 stars to the current essay': 201,
#  'what is the weather here': 202,
#  'Reserve a table for teresa and elnora at a fast food joint which serves fish and chips': 203,
#  'play Fernando Olvera': 204,
#  'I need a place that serves smelt for a party of 4, preferably a taverna': 205,
#  'Play Henrie Mutuku album from 1957': 206,
#  "Add Testifying to  donna's tokyo rising palylist": 207,
#  'I want to go to Antigua and Barbuda and eat at a table for 4.': 208,
#  'find the trailer for On the Good Ship Lollipop': 209,
#  'Will it be warmer in my current position ': 210,
#  'give this current essay a 3 out of 6': 211,
#  'Will it be freezing one second from now in Aragon, Pakistan': 212,
#  'play Safe Rock And Roll Sucks on Lastfm': 213,
#  'Please pull up Nothing Feels Good': 214,
#  'in Taiwan will there be rainfall in Willimantic': 215,
#  'I am looking for the TV show titled Catchphrase': 216,
#  'Play some twenties theme music on Google Music.': 217,
#  'I give The French Suicide 5 stars': 218,
#  'score this album 5 stars': 219,
#  'I need a restaurant on july 18th in Rose Bud': 220,
#  'Give the current book 5 out of 6 points.': 221,
#  'play Google Music tunes': 222,
#  'add maschi e altri to my this is john williams': 223,
#  "What's the weather forecast for Central, North Dakota?": 224,
#  'Include hohenfriedberger marsch to my Novedades Pop list.': 225,
#  'For the saga The End of a Family Story I give 0 stars': 226,
#  'find Kerasotes Theatres with movie times': 227,
#  'Will it get cloudy in Cliffwood Beach?': 228,
#  'Is The Kiss playing': 229,
#  'Tell me if it will rain on 4/19/2030 in Angola': 230,
#  'Give the Hover Car Racer chronicle two of 6 stars': 231,
#  'I want to give Three Days Before the Shooting... one out of 6 stars': 232,
#  'Find the Son of Man show': 233,
#  "I'd like to watch films at Marcus Corporation at twelve P.M.": 234,
#  "add to anacreon in heaven into the playlist girls' night": 235,
#  'show creativity in Ah': 236,
#  'rate Six Months in Mexico 1 out of 6': 237,
#  'add scarlet begonias to my para entrenar playlist': 238,
#  'Will there be a cloud in Kiribati': 239,
#  'Give one out of 6 to A Week in the Woods': 240,
#  'i want to watch animated movies at Showcase Cinemas': 241,
#  'Give the current novel a rating of 5 out of 6.': 242,
#  'Play a 1964 track from Shahram Nazeri on Pandora.': 243,
#  'this is a 6 rating for the album down to one': 244,
#  'What time do the movies play at Southern Theatres?': 245,
#  'give one out of 6 points to this album': 246,
#  'rate the current book novel 5 out of 6': 247,
#  'I would rate this novel a four': 248,
#  'I want to book a restaurant for ten this summer': 249,
#  'I am looking for Shoot Me Down': 250,
#  'I want to book a restaurant for eight in Harding.': 251,
#  'Looking for the trailer for Shaolin Temple': 252,
#  'Make me a reservation at a bar for a party of 7 in indonesian': 253,
#  "Add this album to sheri's playlist journey": 254,
#  'Please help me find I Want to Take You Higher the game': 255,
#  "I want to hear Shooby Taylor's Tearing Up The Album Charts.": 256,
#  'Rate this textbook 5 out of 6 points': 257,
#  'rate this book 2 of 6\n points': 258,
#  'rate this book titled The Clue in the Old Album one out of 6 stars': 259,
#  'weather at Stanford at six am': 260,
#  'give three out of 6 points in current essay': 261,
#  'find films at Magic Johnson Theatres': 262,
#  'book a spot for 8 at The Kitchin on october the 13th, 2039': 263,
#  'I want to reserve a gastropub that has a spa.': 264,
#  'is Tarzan of the Apes playing at Cobb Theatres': 265,
#  'put four in blue onto Ultimate 00s.': 266,
#  'please put this tune on the irish folk – jigs & reels playlist': 267,
#  'I rate three points for the book The Early Coorgs': 268,
#  'For the saga Leaves from the Inn of the Last Home I give the rating of 1': 269,
#  "I'm giving 0 points to A New Lease of Death.": 270,
#  'Please give me the movie schedules.': 271,
#  "What's the weather in Stamps": 272,
#  'find the photograph Move Any Mountain': 273,
#  'Add this track to the playlist kickass metal': 274,
#  'What movie schedules are at National Amusements': 275,
#  'Add the entire album into indie español': 276,
#  'What time is The Mourner playing at the movie house?': 277,
#  'Where to watch show Extremely Live': 278,
#  'I want the photograph of Walt Before Mickey': 279,
#  'play wendy james from the fifties': 280,
#  'what animated movies are playing at Fox Theatres': 281,
#  'find films at Alamo Drafthouse Cinema': 282,
#  "Add exorcising ghosts to joy's thrash attack playlist": 283,
#  'What time is Between Tears and Smiles playing': 284,
#  "I'd like to go to a pub that has italian dressing for a party of 5 on February 11, 2033": 285,
#  'What is the showtime for Arsho': 286,
#  'Add Julia Fordham to the Massive Soca Hits playlist. ': 287,
#  'What films are scheduled around here?': 288,
#  'Rate The Summer King saga a 1 stars': 289,
#  'Find a novel called East Liberty': 290,
#  'Play teri meri by Josh White': 291,
#  'Play the theme tune that Christian Fennesz wrote': 292,
#  'Book reservations at a restaurant for me and my ex husband in West Virginia': 293,
#  'I rate A Moment in Time  a 5\n': 294,
#  'I give The Road from Elephant Pass four stars': 295,
#  "add the artist to the 90's Baby Makers playlist": 296,
#  'add tune to my playlist picnic in the park': 297,
#  'Add Elkie Brooks to Happy Birthday playlist': 298,
#  'Play Eve': 299,
#  "Play me Benjamin Kowalewicz's top hits": 300,
#  'Will it feel nice here or within the same area': 301,
#  'Add this tune to my playlist named Women of Fresh Finds': 302,
#  'put this frederick knight track on my the midnight hour playlist': 303,
#  "I'd like to eat around ID on august the 16th with a party of 8": 304,
#  "What's the weather in Paulette Yemen": 305,
#  'Play Tanti Auguri A Te from Bruce Gilbert': 306,
#  'Add Geschwisterliebe to my string theory playlist. ': 307,
#  'I give the previous saga 4 out of 6': 308,
#  'find the album Smoke and Mirrors': 309,
#  'Look for the trailer to Hickory Daily Record.': 310,
#  'will the weather be warm in August at the faraway in Micronesia': 311,
#  'I want to take me and my momy to eat in Flossmoor': 312,
#  'Is the weather colder in Costa Rica': 313,
#  "What's the weather like in Serbia": 314,
#  'Find a TV show called Union.': 315,
#  'What time is A Man for Burning playing': 316,
#  'this next essay is worth five': 317,
#  'Add Roots of the Outsiders to Blues Roots': 318,
#  'Is it going to be warm on march the 12th in Pendleton, Delaware?': 319,
#  'Will it be cloudy on Sep. 16 in Palau': 320,
#  "I'd like to book at a place in AR, looking for an oyster bar that is indoor and can accommodate a party of eight that is also within walking distance.": 321,
#  "Let's listen to the most popular Marty Friedman songs on Zvooq.": 322,
#  'What will it be like in six PM at the current place': 323,
#  'Give the current series two stars.': 324,
#  'I want to play the game Show Me the Wonder': 325,
#  'Play the music genre Synthpop': 326,
#  'Play the Mother Lode by Tamio Okuda': 327,
#  'When is Spyforce playing?': 328,
#  'play music by Helen Ward': 329,
#  'Check the weather forecast for Sappho': 330,
#  'Will it be warm here in one hour': 331,
#  'Add this artist to piano chill': 332,
#  'add this song by deron miller to my party on fridays playlist': 333,
#  'How cold is it in my current position?': 334,
#  'book a table at the Irma Hotel in Mount Repose': 335,
#  'I want to rate The Obama Syndrome zero of 6': 336,
#  'Get me a table for 3 within walking distance from my hotel in Tajikistan.': 337,
#  'Tell me if the forecast will be temperate around Nationalpark Doi Suthep-Pui on 4/15/2034': 338,
#  'find the nearest animated movies at a movie theatre': 339,
#  'What films are at Century Theatres in twelve hours': 340,
#  'Book a restaurant for marcella, erma and leanne rivera.': 341,
#  'Play me a fifties song': 342,
#  'Put on Vimeo and play Kacapi Suling': 343,
#  'Play some Sabah from the eighties': 344,
#  'Find a novel called Nature Reviews Genetics.': 345,
#  'Is it freezing on Jun. the 21st in Apshawa South Africa': 346,
#  'For this novel I give a rating of 4 out of 6\n': 347,
#  'What animated movies are there nearby?': 348,
#  'find Manthra Mothiram at Century Theatres': 349,
#  'I want to add Black Ribbons to the i love my neo soul playlist': 350,
#  'Book me a reservation for an outdoor restaurant': 351,
#  'show the schedule of movie The Statue': 352,
#  'add Coordinates of Confusion to bass face playlist': 353,
#  'Book a bakery that serves souvlaki for tomorrow.': 354,
#  'add take it back to my Metal Party playlist': 355,
#  'I need to book a reservation in Searsport at eleven am': 356,
#  'Play some acapella music on Iheart': 357,
#  'Show me the photograph called Hola Mary Lou: Prom Night II.': 358,
#  'Will it rain here at 13:22:09?': 359,
#  'Show me TV series Lego Star Wars 3: The Clone Wars': 360,
#  'Listen to music from 1975': 361,
#  'where is The Adventure of the Yellow Curl Papers playing': 362,
#  'add my old kentucky home to Fresh Finds Fire Emoji': 363,
#  'Find the schedule for movie times.': 364,
#  'United States has warm weather on next Wed.': 365,
#  'rate Eleanor Rigby a 3\n': 366,
#  'Will it be sunny in South Superior?': 367,
#  'find the song Ticks': 368,
#  "I'd like a table for 10 at a distant place downtown for next fall": 369,
#  'I want to hear a full album on youtube by Jem Godfrey': 370,
#  'Let me know what animated movies are playing around here.': 371,
#  'On Itunes play the latest Anna Yesipova ep': 372,
#  'show me the picture Unfinished Monkey Business': 373,
#  'Add Metal Gear Solid 2 Sons of Liberty Soundtrack 2 The Other Side to edna st vincent millay': 374,
#  'Will it be foggy on the town meeting day vermont in Angola': 375,
#  'give a 5 to A Picture of Her Tombstone': 376,
#  'Where can I view the picture of Workin’ with the Miles Davis Quintet': 377,
#  'I want to book a delicatessen serving testaroli in Somalia for 7/25/2027.': 378,
#  "What's the weather like in Mountainair": 379,
#  'Play some 50 Shades of Love': 380,
#  'add Monster Monster to my throwback thursday playlist': 381,
#  "What's the weather forecast for tomorrow around Sankertown?": 382,
#  'I want to World of Warcraft: Tides of Darkness ': 383,
#  'Which animated movies are playing in the neighbourhood and when?': 384,
#  'book me a Rustic inn restaurant for 8 members at Nappanee': 385,
#  'Show the Mickey Mouse photograph': 386,
#  'Play music from 1976 on Deezer': 387,
#  'What will the weather be like in the Falkland Islands starting may 25, 2022': 388,
#  'I think this novel gets 1 stars': 389,
#  'Add the artist  tony thompson to my canta en la ducha playlist': 390,
#  'book a latin cuisine pub for 2 on September the 13th, 2037 in Kazakhstan': 391,
#  'Open Deezer and play top 40 hits': 392,
#  'Where can I watch the TV series The Trifecta?': 393,
#  'What are the movie times at Landmark Theatres': 394,
#  'Is Salò the TV show available to watch anywhere?': 395,
#  'Play music which has humour on Youtube.': 396,
#  'I think Memorial Day should have a rating value of 3 and a best rating of 6': 397,
#  'Play Eddie Meduza from the thirties': 398,
#  'add Irish Heartbeat to my Trapeo playlist': 399,
#  'Rate the current essay a three points': 400,
#  'Play playlist Chilled R&B': 401,
#  'play a Morton Downey record with Slacker': 402,
#  'Rate this book 0 of 6 points': 403,
#  'Give this album 4 out of 6 stars': 404,
#  'The book Choper, Coffee, Gilson should get a zero': 405,
#  'find Naomi & Wynonna: Love Can Build a Bridge': 406,
#  "I'd like showtimes for The Story of Wish You Were Here.": 407,
#  'Play a tune from Space Mandino.': 408,
#  'Please put an album by Joseph Meyer on my POP GOES THE 80s playlist': 409,
#  'show painting of Waiting for Snow in Havana': 410,
#  'I would like to book at a pub on mar. 8, 2020 that is close to Broadway-Lafayette St for my daughters and I.': 411,
#  'book a spot in Netherlands Antilles': 412,
#  'Find a television show called Structured Fax File.': 413,
#  'Find a reservation for eight at Rhodes Twenty Four in GU': 414,
#  'Need to book a restaurant in PA in the city of Old Orchard Beach': 415,
#  'At AMC Theaters what is the movie schedule?': 416,
#  'Open Lastfm and play a voluntad del cielo from Wax': 417,
#  'Rate this current essay a zero.': 418,
#  'add Hemanta Kumar Mukhopadhyay album in Funky Jams': 419,
#  'What movie schedules are animated movies close by': 420,
#  'I give this essay three of 6 stars': 421,
#  'Show me the album Apache Axis2': 422,
#  'Rate The Purcell Papers two out of 6 stars': 423,
#  'add LISA to my playlist Street Dance': 424,
#  'book a spot for 3 at supper time in IL': 425,
#  'I want to read the book The Minotaur': 426,
#  'RAte the Black Coffee chronicle three out of 6 stars': 427,
#  'find Cut the Rope': 428,
#  'I want to see Dead Calm at the closest cinema': 429,
#  'find Join the Dots: B-sides and Rarities': 430,
#  'Play chant music by pappu venugopala rao on Slacker.': 431,
#  'Look up The Making of Milwaukee': 432,
#  'Tell me when it will be warmer in Woods Hole, Oklahoma': 433,
#  'I give Life During Wartime a one out of 6.': 434,
#  'is it supposed to get colder here on 12/28/2019': 435,
#  'Can you find My Island Home TV series?': 436,
#  'Where can I locate Leo the Lion for purchase': 437,
#  'What will it be like feb. the twentieth in Colorado': 438,
#  'play robert fripp sound track on Pandora': 439,
#  "I'd like a table in a smoking room in a taverna on sep. 23, 2023": 440,
#  'Play the best chant of 1975': 441,
#  'Find me the show Krypto the Superdog': 442,
#  'I wish to enjoy some fifties music by Johnny Paycheck.': 443,
#  'play a track by Alpha Blondy with Deezer': 444,
#  'Can you find the soundtrack for Fast Food Nation': 445,
#  "I'd like to find Scriptures of the Golden Eternity TV series": 446,
#  'Please help me search The Banker television show.': 447,
#  'Which films are playing at the closest cinema?': 448,
#  'Can you add psycho to Canciones que lo van a petar?': 449,
#  'show me the schedule of movie times in Dipson Theatres': 450,
#  'Find painting Big Ideas': 451,
#  'what is the weather forecast for Piqua on Pearl Harbor Remembrance Day': 452,
#  'what will the weather be in Double Oak at 12 am': 453,
#  'Put Jazzy B on Lazy Chill Afternoon playlist': 454,
#  'show Angels of Iron television show': 455,
#  'I want to book a restaurant for nine with wifi': 456,
#  'I need reservations in ND in the city of Briarwood for me and my colleagues.': 457,
#  'Find a show called Star Trek: Starfleet Academy Starship Bridge Simulator.': 458,
#  'show me the picture Sex and Drugs and Jesus Christ': 459,
#  'Book a table for doris and I in New Tulsa': 460,
#  'Show me animated movies that are playig at Great Escape Theatres': 461,
#  'What is the weather for Cormorant, ME\n': 462,
#  'Look for Hail Satanas We Are The Black Legions': 463,
#  'Show the forecast for two years from now in Lake Telemark Sudan': 464,
#  "I'd like to see the photograph The Light": 465,
#  'What time around here can I fins animated movies': 466,
#  'Is it forecast to be warm in Bosnia and Herzegovina?': 467,
#  'show movie times for AMC Theatres': 468,
#  'Book a northeastern brazilian restaurant for 10 am': 469,
#  "What's the weather forecast for Pointe-Heath Ecological Reserve at midnight?": 470,
#  'Please get me The National Medical Journal of India game.': 471,
#  'Open Youtube and play Connie Francis Sings Spanish And Latin American Favorites from Yukiko Iwai': 472,
#  'give 0 out of 6 points to this album': 473,
#  'Will there be a blizzard at 2 am in my current place': 474,
#  'Tell me when it will be warmer in my current position': 475,
#  'Will there be snowfall this month in UT': 476,
#  'Book the Ballylickey House for 7/16/2027.': 477,
#  'play music by Bonobo': 478,
#  'put the mike oldfield album onto my La Mejor Música para tus Fiestas playlist': 479,
#  'how much humidity in Mancos': 480,
#  'play the song Shine A Light': 481,
#  'add abrar ul haq to Confidence Boost': 482,
#  'Add this artist to my This Is Philip Glass playlist': 483,
#  'The Get Going playlist needs another song.': 484,
#  'Find a saga called Story of My Life.': 485,
#  'Add Sunday Express Live to workout playlist': 486,
#  'what will the weather be in Port Costa FM will it be foggy': 487,
#  'find a show called The Crowd Roars': 488,
#  'I want to give Think Like a Freak one stars': 489,
#  'Which films are playing close by?': 490,
#  'Will there be wind in Loyola?': 491,
#  'What will the weather be like not far from Alabama on May 9, 2037?': 492,
#  'Is Love and Other Troubles playing': 493,
#  'Book a table for 8 at a pub in North Carolina': 494,
#  'Play some Last Fm music like the 1992 ep from Peaches': 495,
#  'give a zero rating to May We Borrow Your Husband?': 496,
#  'Is it hotter in Vernon': 497,
#  'find the novel Meg and Seron': 498,
#  'Add this tune to my wine & dine playlist': 499,
#  'show TV show named I Fell in Love with a Dead Boy': 500,
#  'What time is Always Brando showing': 501,
#  'play Groove Shark folk-rock': 502,
#  'Add this song to my the perfect italian dinner playlist': 503,
#  'find Live in Tokyo for me': 504,
#  'Play a Jack Lawrence concerto': 505,
#  'Season of the Witch: How the Occult Saved Rock and Roll gets five points': 506,
#  'Add Joey Fatone to my Spotlight on Country 2016 playlist': 507,
#  'What local movie house is playing Beat the Drum': 508,
#  'Play some chant from 1974': 509,
#  'Find the show Manthan': 510,
#  'Give me the weather forecast for the city of Archie': 511,
#  "Add another track to my Catch 'Em All playlist. ": 512,
#  'put this track on the playlist with the name roadrunner rec new releases': 513,
#  'Will it be sunny in Spain on 3/26/2023?': 514,
#  'What time does Kraken: Tentacles of the Deep play': 515,
#  'rate the following novel one of 6': 516,
#  'play Ngola Ritmos top-ten songs': 517,
#  'please book a restaurant with parking facility at taverna': 518,
#  'rate the current chronicle five stars': 519,
#  'Give me the showtime for Bobby Yeah playing at the cinema': 520,
#  'What is the movie schedules for animated movies in the neighbourhood': 521,
#  'What will the weather be this year in Horseshoe Lake State Fish and Wildlife Area?': 522,
#  'Add viktor merjanov to california rock state': 523,
#  'Is The Suicide Shop playing at Southern Theatres': 524,
#  'Play some 1982 movement music on Slacker': 525,
#  'What theater is showing From Paris with Love and when?': 526,
#  'Put this artist on instrumental study playlist': 527,
#  'Will it be hot on orthodox good friday in Michigan and close-by': 528,
#  'play the album How Insensitive': 529,
#  'What is the closest movie theatre that is playing Moment to Moment?': 530,
#  "I'm craving mac and cheese. Book a table at a Portland Mills, KS restaurant. I need it for one second from now": 531,
#  "What's the weather like in Schenectady MA?": 532,
#  'What movie theatre playing animated movies is the closest': 533,
#  'Add the song to the pure seduction playlists': 534,
#  'find Word of Mouth for me': 535,
#  "Add gene clark to diann's chill out list": 536,
#  'Give the current book im reading zero points out of 6.': 537,
#  'Add splendido hotel to my verano forever': 538,
#  'I want to give the current novel 5 out of 6 points': 539,
#  'Book a highly rated coffeehouse for four people.': 540,
#  'stacy watson and adriana want to go to the best osteria in Hallowell Minnesota this afternoon': 541,
#  'rate this chronicle a 0': 542,
#  'Find a soundtrack called Top Gear Australia.': 543,
#  'play some Classical music on Spotify': 544,
#  'I need a diner': 545,
#  'I want to give this album 3 points': 546,
#  'Get me a table at a bar which has a spa.': 547,
#  'I want to give this current novel 4 points': 548,
#  'Find the movie schedules for Speakeasy Theaters.': 549,
#  'Is The Matinee Idol 06:30 cinema sold out?': 550,
#  "I need reservations at a restaurant at 20 o'clock in FM": 551,
#  'show Air Cuan Dubh Drilseach': 552,
#  'give 5 out of 6 points to Short Trips: A Universe of Terrors': 553,
#  'find films at Showcase Cinemas': 554,
#  'Play some 1970 Antero Manninen on zvooq.': 555,
#  "I'd like to put Ryō Yamazaki onto my sylvia plath playlist.": 556,
#  'I need current movie schedules.': 557,
#  'Book a table for ten people in Eucalyptus Hills.': 558,
#  'What is the weather forecast for Winger': 559,
#  'Open Netflix and play Kan Man Gifta Sig I Jeans?': 560,
#  'For the Star Theatres is The Belles of St. Clements playing in 8 minutes ': 561,
#  'Weather for noon in CA': 562,
#  'give four out of 6 stars for this chronicle': 563,
#  'I would give this textbook a rating of 0 and a best rating of 6': 564,
#  "What is the weather going to be like on st. patrick's day?": 565,
#  'show creativity of The Greatest Movie Ever Sold': 566,
#  'I want to listen to the soundtrack Bed of Roses': 567,
#  'Play Tina Cousins from 1956': 568,
#  'book for two in Jordan that is close': 569,
#  'when is Good Will Evil playing at Loews Cineplex Entertainment': 570,
#  'give Heartland chronicle four points': 571,
#  'play This Is Colour by Panda Bear': 572,
#  'Play the soundtrack that Tom Bellamy contributed to': 573,
#  'Is it windy in Custar': 574,
#  'Please tell me the movie times  ': 575,
#  'Is it forecast to be stormy close to Nimule-Nationalpark 1 hour from now?': 576,
#  'I need to know the forecast for two am in Grand Lake Towne': 577,
#  'find Bullet and a Target, a television show': 578,
#  'add a song by Masayoshi Yamazaki to my this is Los Fabulosos Cadillacs playlist': 579,
#  'Play some folk-rock music': 580,
#  'What Howards End cinema is near?': 581,
#  'Can I see the TV show The Closer I Get?': 582,
#  'Add tune to Classical Intimate Dinner': 583,
#  "What's the weather forecast for my current spot?": 584,
#  'Find City of Light.': 585,
#  'show freezing forcast now within the same area in North Dakota': 586,
#  "add country favorites willie nelson style to my playlist titled Spinnin' Records Top 100": 587,
#  'Find A New Machine': 588,
#  'book a spot at the best steakhouse in Florida': 589,
#  "I'd like to book 4 seats at a restaurant.": 590,
#  'Book The Mustard Seed in Turks and Caicos Islands for 9 people.': 591,
#  'Give me the schedule for What a Wonderful Place at Cinemark Theatres': 592,
#  'Find the schedule for Metallica Through the Never.': 593,
#  'Play me a fifties song by Chingy': 594,
#  'show Texas Review of Entertainment & Sports Law creative song': 595,
#  'What time is Balkan Rhapsodies: 78 Measures of War playing at Malco Theatres?\n': 596,
#  'add Hey, Johnnie Cope, Are Ye Waking Yet to year in metal 2016 playlist': 597,
#  'find movies at the nearest cinema': 598,
#  'Give this book a rating of 3 out of 6 points.': 599,
#  'put Limey onto my this is astor piazzolla list': 600,
#  'Please add a track from jeff mills to my hiphop hot 50 playlist': 601,
#  'Can you play a 1967 soundtrack on Slacker': 602,
#  'play Zvooq Night Rider list': 603,
#  'find Plitt Theatres now showing Poverty and Nobility': 604,
#  'Open Youtube and play Iron Mountain Depot from John Lomax': 605,
#  'Find me the movie schedules at Fox Theatres': 606,
#  'Play Arif music from the fourties.': 607,
#  'find Young Miss Holmes': 608,
#  'I want to hear Choice on Last Fm from the twenties.': 609,
#  'Give this current book zero out of 6': 610,
#  'play Roy Orbison tunes now': 611,
#  'Book a reservation for a restaurant serving wontons for ten people in Leopold': 612,
#  'Rate the current book a zero of 6': 613,
#  'turn on Last Fm to listen to Chara ballad from 1988': 614,
#  'Play Eternally by Marko Desantis on zvooq.': 615,
#  'Add the artist tom cochrane to new york groove': 616,
#  'show me the schedule of Outlaw of Gor at nearest movie house at 5 A.M.': 617,
#  'Will the wind die down at my current location by supper time?': 618,
#  'I need a reservation for Cashel Palace Hotel in California for a party of 9': 619,
#  'Will rainfall continue here tomorrow?': 620,
#  "I'd give A Man Called Ove a 1": 621,
#  'what is the weather at my current location': 622,
#  'Put this album on totally alternative': 623,
#  'Play movement music from 1954': 624,
#  'rate The Pagan Christ zero points out of 6': 625,
#  'add this song to my Canción del Día playlist': 626,
#  'Please add Liberty Forever to the road trip playlist.': 627,
#  'I want to listen to the soundtrack The Om Years': 628,
#  'add hold tight to my throwback party': 629,
#  'Where can I see the trailer for Phineas Redux?': 630,
#  'What are the movie schedules for films in the area?': 631,
#  'give three stars to chronicle Falling in Love With Hominids': 632,
#  'Is it chillier in Baconton KY': 633,
#  'add Tarte to bandas sonoras playlist': 634,
#  'Give me a weather forecast for CA': 635,
#  'play the greatest 1972 album by Wes Dakus': 636,
#  'Add Ashley McIsaac to my r&b party classics playlist': 637,
#  'give me the movie schedule for animated movies showing in the neighborhood': 638,
#  'the stars for this are 4 for a textbook': 639,
#  'Is it going to be temperate at six am in Washington': 640,
#  'play a good John Maher record with Netflix': 641,
#  'Will it be hotter in Pecan Grove': 642,
#  'show creativity of Pocket Full of Kryptonite': 643,
#  'find movie schedules for AMC Theaters': 644,
#  'Rate this album a five': 645,
#  'Please make reservations for three at a kosher taverna nearby our secondary residence ': 646,
#  "What's the weather forecast for next week at my current position?": 647,
#  'Give this series 4 stars': 648,
#  'add Heat of the Night to my Novedades Viernes Sudamérica playlist': 649,
#  'Play me something Miles Davis did with a symphony': 650,
#  'I give the current essay a two': 651,
#  'Rate this chronicle three of 6 stars': 652,
#  "What's the forecast for Georgia?": 653,
#  'Will it be colder 1 hour from now noew in East Dundee Zimbabwe': 654,
#  'What will the weather be in Deer River?': 655,
#  'What is the movies playing at North American Cinemas': 656,
#  'What weather will it be in Battlement Mesa?': 657,
#  'Play Shinya Yamada music from 1962 on Groove Shark ': 658,
#  'search for movie Turn Back the Clock': 659,
#  'Give Northern Lights Audio 5 / 6 points': 660,
#  'I give Jonathan Livingston le goéland 2 of 6 points': 661,
#  'will it rain today in French Southern Territories of Highland Beach\n': 662,
#  'Play a cohesive playlist for me': 663,
#  'four points for this essay': 664,
#  'Book a bakery with smoking room for nine in Niger.': 665,
#  'Rate this album 0 points out of 6': 666,
#  'book a table for eight in Graf far away': 667,
#  'What is the weather at the current position': 668,
#  'Give this novel two points': 669,
#  'Add sugarolly days to my list, your favorite slaughterhouse': 670,
#  'What will it be like in the current place at midnight': 671,
#  'I gave the current album two stars': 672,
#  'I need a schedule for the cinema that is showing The Shiralee': 673,
#  'I need to book a table for 7 in Estonia': 674,
#  'find Long Hello and Short Goodbye, a movie': 675,
#  'I rate the current textbook a 0 of 6': 676,
#  'find start time in 12 seconds for National Bomb': 677,
#  'give two out of 6 stars saga called The Big Question': 678,
#  'I want the film for nearest movie theatre': 679,
#  'The Forest should be rated a four': 680,
#  'Please look up the painting Beyond Iconic: Photographer Dennis Stock.': 681,
#  'Find the Endangered Species song': 682,
#  'BOok a table for me and georgina at a pub in a spa': 683,
#  'Find the schedule for films at the closest movie house.': 684,
#  'What time is 30 Days of Night playing?': 685,
#  'when can i see Red Hot Tires': 686,
#  "Find a reservation within walking distance of pauline's place for a party of 10 at fourteen o'clock at a restaurant that serves aioli": 687,
#  'Play Wynton Kelly music on Netflix sort by popular': 688,
#  'What is the best restaurant in Kentucky for ten at 0 am': 689,
#  'Book a table somewhere in Dominica for 2 minutes from now': 690,
#  'Find the schedule for animated movies in the neighborhood.': 691,
#  "Play Masashi Hamauzu's newest symphony on Itunes.": 692,
#  'Is A Charming Man playing at lunch time?': 693,
#  'find the closest showing of The Taste of Others at a cinema': 694,
#  'Add De Principii Evangelikum to my Domingo Indie palylist': 695,
#  'add Matthew Helders artist in Showstopper Being Mary Jane': 696,
#  'book a restaurant for one': 697,
#  'find The Panic in Needle Park': 698,
#  'How do I get the soundtrack for Hearts of Fencing?': 699,
#  'Find The Passion of Michel Foucault novel': 700,
#  'Find the movie schedules for movies close by': 701,
#  'Play playlist riveting ': 702,
#  'I want to give Among the Enemy 4 out of 6 points': 703,
#  'I rate Cold Tom four points and a best value of 6': 704,
#  'What will the weather be in a month from now at my current location?': 705,
#  'Play some eighties movement music': 706,
#  'book for lobster newberg this week in Malaysia at a restaurant for four': 707,
#  'I want to rate the current textbook with 4': 708,
#  'Add cecil womack to my 50 Great Female Voices playlist.': 709,
#  'What will the weather be here 14 minutes from now within walking distance?': 710,
#  'Book a restaurant in Donnelly': 711,
#  'show creativity of All for One': 712,
#  'Play me a popular song by Koichi Domoto': 713,
#  'Book a reservation for a party of six in the same area  as Metropolitan Borough of Bethnal Green': 714,
#  'Is it cold in Windhorst': 715,
#  'I want Tanya Stephens in my 35 Soul Classics 1970 to 1975 playlist. ': 716,
#  'Play Oliver on pandora.': 717,
#  'What movies are playing at Marcus Corporation?': 718,
#  'Need a table in Serbia and Montenegro on Apr. 16 for a party of seven': 719,
#  'I want to rate the Children of This Earth chronicle a rating value of 1 and a best rating of 6': 720,
#  'Rate The Last Opium Den 0 points': 721,
#  'I would like to add to my plalist, Visjoner onto the old school metal one': 722,
#  'What time is Doc Savage: The Man of Bronze playing': 723,
#  'Find a soundtrack called The Alice Cooper Show.': 724,
#  'find 300: March to Glory, a song': 725,
#  'I want this chronicle to get a rating of 4': 726,
#  'Can you help me find the television show Women and Death': 727,
#  'I need a reservation for february 27, 2020 at a bar that serves paté': 728,
#  'find a painting called The Other Bank': 729,
#  'Find the Innocent When You Dream saga': 730,
#  'show creativity of The House of the Dead': 731,
#  'Rate The Change 0 out of 6 points': 732,
#  'find Becoming Royston': 733,
#  'look for the game Find Another Way': 734,
#  'play a concerto from sam sparro': 735,
#  'Rate Deception a one': 736,
#  'Tell me what films are playing at Plitt Theatres': 737,
#  'Play a track by Titiyo': 738,
#  'add song by charlie hunter to Rumba y más': 739,
#  'Find Live at Bonnaroo.': 740,
#  'Tell me the movie schedules': 741,
#  'book a spot at a pizza place nine weeks from now in Wisconsin': 742,
#  'add artist steve cropper to Rhythm and Blues': 743,
#  'Book me a table for 4 in a restaurant in United Kingdom.': 744,
#  'book a spot for nona gray, myrtle and alison at a top-rated brasserie that is distant from Wilson Av on Nov. the 4th, 2030 that serves ouzeri': 745,
#  'Play the song Aura II: The Sacred Rings': 746,
#  'forecast for Morse Shores Kansas': 747,
#  'Please add checkmate to my irish folk – jigs & reels playlist': 748,
#  'I give this current novel zero stars and a best rating of 6': 749,
#  'courtney and ruby want to eat at a restaurant three years from now': 750,
#  'I need work of Father Dearest': 751,
#  'play 2007 tunes by Bunny Berigan': 752,
#  "I need a table for 1 minute from now at any pub for five around IN that also serves fisn'n chips.": 753,
#  'four out of 6 stars for Special Assignments': 754,
#  'Book a restaurant in Myanmar for 4.': 755,
#  'Book a restaurant in San Juan Capistrano for 6 people at ten am': 756,
#  'Add A Bum Note and a Bead of Sweat to my Stress Relief playlist': 757,
#  'I would rate this book chronicle, 3 out of 5 stars.': 758,
#  'Play music from the seventies': 759,
#  'Add Troy van Leeuwen to my nu metal list': 760,
#  'find movies that are nearby': 761,
#  'Can i get the showtimes for films in the area.': 762,
#  'rate this book titled House of Dolls three out of 6 stars': 763,
#  "The Naked and the Dead was pretty good, I'd give it four stars.": 764,
#  'Is it windy in Inlet, Lebanon?': 765,
#  'Will it be freezing at 1 AM in Balko?': 766,
#  'Play Talking To The Universe on Itunes': 767,
#  'book a table not far in WY at a gastropub with internet for me, jenny and antoinette in one week': 768,
#  'book a top-rated osteria seven weeks from now': 769,
#  'Add el choclo to my women of classical list': 770,
#  'in California will it be cold in East Trenton Heights': 771,
#  "I'd like to see Level Headed ": 772,
#  'play top-twenty song from 2015': 773,
#  'What will the weather be in Bayside on Sep. 21, 2034?': 774,
#  "Make a restaurant reservation for me and my son at twenty three o'clock.": 775,
#  'Who published the novel JamesEdition?': 776,
#  'What time are the movie schedules': 777,
#  'find a movie house with Ulterior Motive that is closest': 778,
#  'Find out what films are playing at North American Cinemas': 779,
#  'What is the weather forecast one minute from now in Macao': 780,
#  'What animated movies are playing at Dipson Theatres?': 781,
#  'book a bar with mediterranean food for three people': 782,
#  'Rate this book three out of 6': 783,
#  'Find me the book The Van Dyke Show': 784,
#  "I want to book a highly rated pizzeria in the same area as tia's house": 785,
#  'Rate the current textbook 1 of 6': 786,
#  'Rate this novel 1 points.': 787,
#  'find She Monkeys': 788,
#  'add Rak biszewilo to my playlist named Jazz': 789,
#  'What animated movies are around here': 790,
#  'Find me the picture The Id': 791,
#  'Will it get windy close by here?': 792,
#  'book The Middle East restaurant in IN for noon': 793,
#  'Listen to Power Gaming playlist': 794,
#  'find a TV show called Randy Scouse Git': 795,
#  'Add hello i must be going to the power ballads playlist': 796,
#  'Which films are playing at the closest movie house?': 797,
#  'Is it going to rain in Kansas by march 4': 798,
#  'Search for the Abel Sánchez: The History of a Passion novel': 799,
#  'I want to see the television show The Muppet Christmas Carol': 800,
#  'Add an artist to my Hype list': 801,
#  'I want lance king in my list called One Love': 802,
#  'Rate The Simon & Schuster Encyclopedia of Dinosaurs and Prehistoric Creatures 0 points.': 803,
#  "Can you put Musiri Subramania Iyer's song onto the lo-fi love soundtrack?": 804,
#  'Find a table somewhere for me and my step mother in Graniteville DE': 805,
#  'Book a restaurant for one for this month.': 806,
#  'Play Oj, Jelena, Jelena, Jabuka Zelena by Ler Lalonde.': 807,
#  'Play Acid Punk music.': 808,
#  'give The Judas Tree a zero': 809,
#  'add track to kickass metal': 810,
#  'What weather will HI have will there be hail twenty one minutes from now': 811,
#  'Add the tune to my Epic Classical playlist.': 812,
#  'add this album to my de camino a clase playlist': 813,
#  "What's the weather forecast for 8 hours from now in Cape Verde?": 814,
#  'Give 5 / 6 stars to Expressive Processing': 815,
#  'Play some Eddie Vinson on Deezer': 816,
#  "I'm looking for The Birth of a Nation": 817,
#  'I want a table for my grandson and I somewhere in Arkansas': 818,
#  'I want to book a table for me and my boss at Glassy Junction in Turkey.': 819,
#  'Find Night of Passion': 820,
#  'Play music from Hide': 821,
#  'I need a table in East Timor for a party of nine at 5 North St': 822,
#  'List films at Pacific Theatres': 823,
#  'Where can I see The Somme starting at 16:01:04?': 824,
#  'rate the current essay a 0 for me': 825,
#  'Tell me the weather forecast in 4 years and a half in GA': 826,
#  'add The Little House We Built onto mucho rap': 827,
#  'book a table in Tennessee for 1 for next August': 828,
#  'Put Slimm Cutta Calhoun on my Songs to Sing in the Car playlist': 829,
#  'Find Stained Glass Windows.': 830,
#  'give 4 out of 6 points to this book': 831,
#  'I need a novel about Polymer Chemistry.': 832,
#  'I wish to listen to good symphony music by mi lu bing.': 833,
#  'Play Metal Crash Course playlist.': 834,
#  'what is the forecast for Wren for freezing weather': 835,
#  'Show me the TV show My Only Wish': 836,
#  'find the trailer for Hit the Ice': 837,
#  'find the video game The Sims 3: Generations': 838,
#  'Will it be foggy at sunset in Red Devil': 839,
#  'Search for the Halfway Home TV show': 840,
#  'In Portales Gambia what is the humidity this morning': 841,
#  'book a spot at a restaurant with wifi that is neighboring Suriname': 842,
#  'Is it going to be freezing in one hour in Puerto Rico': 843,
#  'I want to add something by Jarvis Cocker to my rock español playlist': 844,
#  'play Latina': 845,
#  'Play The Crowd: A Study of the Popular Mind soundtrack': 846,
#  'Add a norma jean tune to the Soul Revived playlist. ': 847,
#  'Rate the current novel 1 of 6': 848,
#  'Find a photograph of Time Loves a Hero': 849,
#  "What's the weather forecast for here in august?": 850,
#  'For Adaptive Coloration in Animals I give 4 points': 851,
#  'book a highly rated bar in Curacao for one': 852,
#  'search for the game The Last Horror Movie': 853,
#  'Show me the Only the Strong Survive photograph': 854,
#  'What are the movie schedules at Loews Cineplex Entertainment': 855,
#  'Show me a movie theatre where Screamplay is playing': 856,
#  'I need to book an indoor pub in Strabane': 857,
#  'Add this track to epic wall of sound': 858,
#  'What is the weather here': 859,
#  'Find a soundtrack called The Dragon.': 860,
#  'Find the schedule for the closest films at a cinema at meal time.': 861,
#  'Find me the novel, Between the Rivers.': 862,
#  'Add dr know to my TODO ALTERNATIVO playlist. ': 863,
#  'What time is Southern Theatres showing Ukraine Is Not a Brothel?': 864,
#  'add Paloma negra to my Funky Jams list': 865,
#  "What animated movies are playing close by at four o'clock?": 866,
#  'Add Hatfield and the North to my Hot House playlist. ': 867,
#  'please add this track to my de camino playlist': 868,
#  'show creativity of video game Labyrinth': 869,
#  'Show me the work titled The Perfect Gentleman which is a song': 870,
#  'find a television show called Tiny Dancer': 871,
#  'During tea time, what animated movies will be screening at the closest movie house?': 872,
#  'book a table for now for 4 for an oyster bar': 873,
#  'Rate my current textbook three out of 6': 874,
#  'Give the current series a one.': 875,
#  'Will there be a blizzard in Egypt on Jul. 3?': 876,
#  'Book a table for 3 at one of the Restaurants in Washington, D.C. in Riverview': 877,
#  'play the album Sauna on Zvooq': 878,
#  'Do you know if it will be chilly today in Puerto Rico': 879,
#  'Can you locate the work, Warlock 2: The Exiled?': 880,
#  'Please book me a reservation this year for a restaurant within the same area of my office': 881,
#  'Is Race Gurram playing': 882,
#  'rate Lost Empires of Faerûn five of 6 stars': 883,
#  'rate The Braindead Megaphone series zero out of 6 points': 884,
#  "What's the weather like in North Brunswick Township Virginia": 885,
#  'Place Raise Your Fist onto year in metal 2016.': 886,
#  'show creative work of Through the Back Door': 887,
#  'What are the movie times for movies premiering in the neighbourhood ': 888,
#  'Where can I find the movie schedules?': 889,
#  'Is Unsettled Land playing at the movie theatre': 890,
#  'Rate Making Sense of Marx 2 stars.': 891,
#  'I want to eat at a scandinavian restaurant that is highly rated in Bonita Texas': 892,
#  'How do I see the TV series To See the Invisible Man?': 893,
#  'Rate the current textbook one stars': 894,
#  'fimd Glory': 895,
#  'Please play Got The Time': 896,
#  'play songs on Itunes': 897,
#  'I give The Beatrice Letters 2 out of 6 stars.': 898,
#  'What is the price for the album Praise the Lord and Pass the Ammunition?': 899,
#  'shawn lane should be moved to my Cena con Amigos playlist': 900,
#  'add song to This Is Philip Glass': 901,
#  'add this artist to my Guilty Pleasures playlist': 902,
#  'play some Origa on Google Music': 903,
#  'I want a Mi Lu Bing song in my Pop Dance playlist. ': 904,
#  'Award a rating of 2 stars out of 6 to Confessions of an economic hit man': 905,
#  'Play best fourties from david izquierdo on album': 906,
#  'Book a close by brasserie in NC.': 907,
#  'what is the forecast for hot temps in Ocean Park': 908,
#  'find seven AM movies at Dipson Theatres': 909,
#  'what is the weather forecast this week close-by my current position': 910,
#  'Where can I find Appalachian Journey': 911,
#  'Add artist hex hector to my old school death metal playlist': 912,
#  'Find movie times.': 913,
#  'Give me the showtimes for animated movies at the nearest cinema.': 914,
#  'I want to hear the album Suites & Sweets': 915,
#  'find films scheudle in the neighborhood at 2': 916,
#  'Where is the nearest cinema that is playing films': 917,
#  'I want another song in the Women of Latin Music playlist. ': 918,
#  'show movie times now': 919,
#  'Add afdlin shauki to La Mejor Música Dance 2017': 920,
#  'Add Leah Kauffman to my uncharted 4 nathan drake playlist': 921,
#  'Rate the current essay a five': 922,
#  'Rate Canto for a Gypsy two of 6 stars': 923,
#  'How is the weather in Getzville, Minnesota?': 924,
#  'What animated movies are showing in the area?': 925,
#  'Book a reservation for a gastropub serving liver and onions': 926,
#  'Give me the movie schedules for Neighborhood Cinema Group': 927,
#  'Play music from 1958.': 928,
#  'add this song to Rock Party': 929,
#  'Play some 1962 theme music.': 930,
#  'Give The Abstinence Teacher 4 out of 6': 931,
#  'find a picture called How Much Wood Would a Woodchuck Chuck': 932,
#  'What will the weather be in Totowa Guernsey?': 933,
#  'Find the schedule for Death Valley Manhunt.': 934,
#  'play Luis Alfonzo Larrain from 1995': 935,
#  "I'd like to see the painting Empire of Two Worlds": 936,
#  'Can I get the showtimes for The Kitchen Toto at Cineplex Odeon Corporation.': 937,
#  'What movies are playing at the closest movie house?': 938,
#  'Book a restaurant reservation in Hong Kong': 939,
#  'find a nearby movie schedules for movies': 940,
#  'book a spot for 6 in Pilot Mound Palau on feb. the twenty-fourth': 941,
#  'Find Head Start': 942,
#  'book a spot for one at a restaurant in ID': 943,
#  'add this artist to the playlist called Fusion Fest': 944,
#  'find Fox Theatres with The Caretaker': 945,
#  'What time is The Daring Dobermans playing': 946,
#  'Look for a photograph of Tailwind': 947,
#  "I'd like to find the Limited Lovers novel": 948,
#  'Add ramble on to Halloween Teens': 949,
#  'Book a spot at a taverna for my cousin and I in Burundi': 950,
#  'search for the show Champagne Showers': 951,
#  'Rate this book 3 out of 6 points': 952,
#  'rate in stars as a 6 for Lord of the Shadows which gets a four': 953,
#  'give three out of 6 points to Blackbox': 954,
#  'What is the weather supposed to be like on Sep. 20 in Maltby, Russia': 955,
#  'will it be freezing in New Ringgold Nebraska': 956,
#  'play the most popular Miles Jones track': 957,
#  'Can I hear the song Visual Audio Sensory Theater?': 958,
#  'Show me the game Music Bank': 959,
#  'Add an album by cowboy troy to my piano in the background playlist.': 960,
#  'I want to find the video game Masada Anniversary Edition Vol. 3: The Unknown Masada': 961,
#  'book a table with wifi in Delaware at a restaurant in one minute': 962,
#  'Rate The Rats chronicle 5 of 6': 963,
#  'put this album on r&b movement': 964,
#  'Give me a list of movie times for films in the area.': 965,
#  'Play music by Janet Paschal': 966,
#  'I give Emile, or On Education five points.': 967,
#  'Look for the American Journal of Sociology': 968,
#  'Play me a 1990 sound track': 969,
#  'Add album to all out 00s': 970,
#  'Can you play a top 5 song by Manos Hadjidakis': 971,
#  'Can you add something by Snow onto my Zen Focus playlist': 972,
#  'Add album to Acoustic Spring': 973,
#  'Is it chilly anywhere faraway from my current place': 974,
#  'add steve winwood to my playlist old school metal': 975,
#  "Add a track to my girls' night playlist.": 976,
#  'Play a 2004 song by eliel on Zvooq.': 977,
#  'Will it be rainy faraway in Charleston Lake Provincial Park in 13 hours?': 978,
#  'I give Benson-Meditation 1 out of 6 stars.': 979,
#  'Show me the movie schedules': 980,
#  'Book a table at a bar in Moody for deloris, ester and petra alvarez.': 981,
#  'Can i get the showtimes for Man in Blues?': 982,
#  'Is there a snowstorm in Russia': 983,
#  'Find a show called The Inheritors': 984,
#  'play Clifford Brown All Stars by Michael Balzary': 985,
#  'play Bra Vibrationer by Dean': 986,
#  'I wish to put tom baxter onto my coffee table jazz playlist': 987,
#  'book a table for one in a bar serving saucisse for meal in Calistoga CO': 988,
#  'give this book a rating of 3 ': 989,
#  'What will the weather be like four seconds from now in South Dakota': 990,
#  'Can you tell me the forecast for East Falmouth, Hungary': 991,
#  "Add the trey gunn tune to my French N' Heavy playlist.": 992,
#  'Play some music from the thirties.': 993,
#  'what is the weather forecast for Red Rock Lakes National Wildlife Refuge': 994,
#  'play the Ashley Tisdale discography TV show': 995,
#  'Play something by Holly Cole on lastfm ': 996,
#  'book a table at a restaurant in Saudi Arabia that serves presskopf': 997,
#  'Make me a reservation in Cedarburg at 0 pm': 998,
#  'Please get seating for me and my children': 999,
#  ...}
